# %% [markdown]
# # SerieTemporal 4 Covid 19 - Análisis básico

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
corona_dataset_csv = pd.read_csv("covid19_Confirmed_dataset.csv")
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region      Lat  ...  4/28/20  4/29/20  4/30/20
# 0            NaN    Afghanistan  33.0000  ...     1828     1939     2171
# 1            NaN        Albania  41.1533  ...      750      766      773
# 2            NaN        Algeria  28.0339  ...     3649     3848     4006
# 3            NaN        Andorra  42.5063  ...      743      743      745
# 4            NaN         Angola -11.2027  ...       27       27       27
#
# [5 rows x 104 columns]

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
corona_dataset_csv.shape
# Out:
# (266, 102)

# %%
corona_dataset_csv.drop(["Lat", "Long"],axis=1,inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...     1939     2171
# 1                           NaN              Albania  ...      766      773
# 2                           NaN              Algeria  ...     3848     4006
# 3                           NaN              Andorra  ...      743      745
# 4                           NaN               Angola  ...       27       27
# 5                           NaN  Antigua and Barbuda  ...       24       24
# 6                           NaN            Argentina  ...     4285     4428
# 7                           NaN              Armenia  ...     1932     2066
# 8  Australian Capital Territory            Australia  ...      106      106
# 9               New South Wales            Australia  ...     3016     3025
#
# [10 rows x 104 columns]

# %%
corona_dataset_csv.groupby("Country/Region").sum()
# Out:
#                     1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                                 ...
# Afghanistan               0        0        0  ...     1828     1939     2171
# Albania                   0        0        0  ...      750      766      773
# Algeria                   0        0        0  ...     3649     3848     4006
# Andorra                   0        0        0  ...      743      743      745
# Angola                    0        0        0  ...       27       27       27
# ...                     ...      ...      ...  ...      ...      ...      ...
# West Bank and Gaza        0        0        0  ...      343      344      344
# Western Sahara            0        0        0  ...        6        6        6
# Yemen                     0        0        0  ...        1        6        6
# Zambia                    0        0        0  ...       95       97      106
# ...

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %% [markdown]
# una de las cosas más interesantes ver como agrego la columna obtenida por group by

# %%
corona_dataset_aggregated.head()
# Out:
#                     Lat     Long  1/22/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                             ...
# Afghanistan     33.0000  65.0000        0  ...     1828     1939     2171
# Albania         41.1533  20.1683        0  ...      750      766      773
# Algeria         28.0339   1.6596        0  ...     3649     3848     4006
# Andorra         42.5063   1.5218        0  ...      743      743      745
# Angola         -11.2027  17.8739        0  ...       27       27       27
#
# [5 rows x 102 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %%
corona_dataset_csv.shape
# Out:
# (266, 102)

# %% [markdown]
# visualization always helps for better understanding of our data.

# %%
corona_dataset_aggregated.loc["China"]
# Out:
# 1/22/20      548
# 1/23/20      643
# 1/24/20      920
# 1/25/20     1406
# 1/26/20     2075
#            ...
# 4/26/20    83912
# 4/27/20    83918
# 4/28/20    83940
# 4/29/20    83944
# 4/30/20    83956
# Name: China, Length: 100, dtype: int64

# %%
corona_dataset_aggregated.loc["China"].plot()

plt.legend()

# %%
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
corona_dataset_aggregated.loc["Spain"].plot()

# %%
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
corona_dataset_aggregated.loc["Spain"].plot()

plt.xlabel('Date')
plt.ylabel('Infection per day')

plt.legend();

# %% [markdown]
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
corona_dataset_aggregated.loc['China'].plot()

# %% [markdown]
# Calculating the first derivative of the curve

# %% [markdown]
# We will use the derivative function in order to better observe which periods stand out and the prominent trend points in infected numbers.

# %% [markdown]
# Eso se va realizando con diff, por defecto diferencia con la columna previa

# %%
print(corona_dataset_aggregated.loc["China"])
corona_dataset_aggregated.loc["China"].diff()
# Out:
# 1/22/20      548
# 1/23/20      643
# 1/24/20      920
# 1/25/20     1406
# 1/26/20     2075
#            ...
# 4/26/20    83912
# 4/27/20    83918
# 4/28/20    83940
# 4/29/20    83944
# 4/30/20    83956
# Name: China, Length: 100, dtype: int64
# 1/22/20      NaN
# 1/23/20     95.0
# 1/24/20    277.0
# 1/25/20    486.0
# 1/26/20    669.0
#            ...
# 4/26/20      3.0
# 4/27/20      6.0
# 4/28/20     22.0
# 4/29/20      4.0
# 4/30/20     12.0
# Name: China, Length: 100, dtype: float64

# %% [markdown]
# y eso nos resulta muy interesante a la hora de poderlo representar por pais

# %%
plt.figure(figsize=(8,5), dpi=100)

# podemos ir eliminando/comentando algunos de los paises para tener mayor visibilidad con el resto

corona_dataset_aggregated.loc["China"].diff().plot()
corona_dataset_aggregated.loc["Italy"].diff().plot()
corona_dataset_aggregated.loc["Spain"].diff().plot()
corona_dataset_aggregated.loc["France"].diff().plot()
corona_dataset_aggregated.loc["Germany"].diff().plot()

plt.xlabel('Date')
plt.ylabel('Infection per day')


plt.legend();

# %%
plt.figure(figsize=(15,20), dpi=50)

#corona_dataset_aggregated.loc["US"].diff().plot()
corona_dataset_aggregated.loc["United Kingdom"].diff().plot()
corona_dataset_aggregated.loc["China"].diff().plot()
corona_dataset_aggregated.loc["Italy"].diff().plot()
corona_dataset_aggregated.loc["Spain"].diff().plot()

plt.xlabel('Date')
plt.ylabel('Infection per day')

plt.legend();
